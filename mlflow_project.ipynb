# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100], dtype=int64))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Define the model hyperparameters
params = {
    "solver": "lbfgs",
    "max_iter": 1000,
    "multi_class": "auto",
    "random_state": 8888,
}

# Train the model
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       270
#            1       0.62      0.50      0.56        30
#
#     accuracy                           0.92       300
#    macro avg       0.79      0.73      0.76       300
# weighted avg       0.91      0.92      0.92       300

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_dict
# Out:
# {'0': {'precision': 0.9456521739130435,
#   'recall': 0.9666666666666667,
#   'f1-score': 0.956043956043956,
#   'support': 270.0},
#  '1': {'precision': 0.625,
#   'recall': 0.5,
#   'f1-score': 0.5555555555555556,
#   'support': 30.0},
#  'accuracy': 0.92,
#  'macro avg': {'precision': 0.7853260869565217,
#   'recall': 0.7333333333333334,
#   'f1-score': 0.7557997557997558,
#   'support': 300.0},
#  'weighted avg': {'precision': 0.9135869565217392,
#   'recall': 0.92,
#   'f1-score': 0.915995115995116,
#   'support': 300.0}}

# %%
import mlflow

# %%
mlflow.set_experiment("First Experiment project")
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics({
        'accuracy': report_dict['accuracy'],
        'recall_class_0': report_dict['0']['recall'],
        'recall_class_1': report_dict['1']['recall'],
        'f1_score_macro': report_dict['macro avg']['f1-score']
    })
    mlflow.sklearn.log_model(lr, "Logistic Regression")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connection.py:398, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     397     self.putheader(header, value)
# --> 398 self.endheaders()
#     400 # If we're given a body we start sending that in chunks.
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connection.py:236, in HTTPConnection.connect(self)
#     235 def connect(self) -> None:
# --> 236     self.sock = self._new_conn()
#     237     if self._tunnel_host:
#     238         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connection.py:211, in HTTPConnection._new_conn(self)
#     210 except OSError as e:
# --> 211     raise NewConnectionError(
#     212         self, f"Failed to establish a new connection: {e}"
#     213     ) from e
#     215 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002B026E206D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 873 (2 times)]
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=First+Experiment+project (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002B026E206D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\utils\rest_utils.py:187, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     186 try:
# --> 187     return _get_http_response_with_retries(
#     188         method,
#     189         url,
#     190         max_retries,
#     191         backoff_factor,
#     192         backoff_jitter,
#     193         retry_codes,
#     194         raise_on_status,
#     195         headers=headers,
#     196         verify=host_creds.verify,
#     197         timeout=timeout,
#     198         respect_retry_after_header=respect_retry_after_header,
#     199         **kwargs,
#     200     )
#     201 except requests.exceptions.Timeout as to:
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=First+Experiment+project (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002B026E206D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mlflow.set_experiment("First Experiment project")
#       2 mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
#       4 with mlflow.start_run():
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\tracking\fluent.py:143, in set_experiment(experiment_name, experiment_id)
#     141 client = MlflowClient()
#     142 if experiment_id is None:
# --> 143     experiment = client.get_experiment_by_name(experiment_name)
#     144     if not experiment:
#     145         _logger.info(
#     146             "Experiment with name '%s' does not exist. Creating a new experiment.",
#     147             experiment_name,
#     148         )
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\tracking\client.py:1240, in MlflowClient.get_experiment_by_name(self, name)
#    1208 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1209     """Retrieve an experiment by experiment name from the backend store
#    1210
#    1211     Args:
#    (...)
#    1238         Lifecycle_stage: active
#    1239     """
# -> 1240     return self._tracking_client.get_experiment_by_name(name)
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\tracking\_tracking_service\client.py:484, in TrackingServiceClient.get_experiment_by_name(self, name)
#     476 def get_experiment_by_name(self, name):
#     477     """
#     478     Args:
#     479         name: The experiment name.
#    (...)
#     482         :py:class:`mlflow.entities.Experiment`
#     483     """
# --> 484     return self.store.get_experiment_by_name(name)
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\store\tracking\rest_store.py:518, in RestStore.get_experiment_by_name(self, experiment_name)
#     516 try:
#     517     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 518     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     519     return Experiment.from_proto(response_proto.experiment)
#     520 except MlflowException as e:
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\store\tracking\rest_store.py:81, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      79     endpoint, method = _METHOD_TO_INFO[api]
#      80 response_proto = api.Response()
# ---> 81 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\utils\rest_utils.py:357, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     355 if method == "GET":
#     356     call_kwargs["params"] = json_body
# --> 357     response = http_request(**call_kwargs)
#     358 else:
#     359     call_kwargs["json"] = json_body
#
# File c:\Users\adegb\miniconda3\envs\mlflow\lib\site-packages\mlflow\utils\rest_utils.py:210, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     208     raise InvalidUrlException(f"Invalid url: {url}") from iu
#     209 except Exception as e:
# --> 210     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to http://127.0.0.1:5000/api/2.0/mlflow/experiments/get-by-name failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=First+Experiment+project (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002B026E206D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
